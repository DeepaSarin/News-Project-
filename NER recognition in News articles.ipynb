# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as  pd
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from spacy import displacy

NER = spacy.load("en_core_web_sm")
df=pd.read_csv('/content/drive/My Drive/PRACTICE/2022SepNewsProject/News Classification Code Files/Cleaned_text_7500.csv')

# %%
text1= NER(df['article'][0])
for word in text1.ents:
    print(word.text,word.label_)
# Out:
# Cargill ORG
# U.S GPE
# Canada GPE
# six CARDINAL
# MINNEAPOLIS GPE
# November 14, 2018 DATE
# Cargill ORG
# six CARDINAL
# North American NORP
# Univar Inc. ORG
# Gillco Ingredients GPE
# International Food Products Corporation ORG
# Batory Foods ORG
# Pearson Sales Company ORG
# today DATE
# one CARDINAL
# Pat Rogers PERSON
# Cargill ORG
# North America LOC
# six CARDINAL
# Cargill ORG
# Univar ORG
# Cargill ORG
# Univar ORG
# the United States GPE
# Canada GPE
# Gillco GPE
# U.S. GPE
# Cargill ORG
# International Food Products ORG
# the United States GPE
# Cargill ORG
# Batory Foods ORG
# Pearson Sales Company ORG
# U.S. GPE
# Cargill ORG
# six CARDINAL
# Cargill PERSON
# six CARDINAL
# North American NORP

# %% [markdown]
# To extract only Nouns from the text

# %%
text1= NER(df['article'][0])
print([chunk.text for chunk in text1.noun_chunks])
# Out:
# ['Cargill', 'food ingredients distribution network', 'U.S', 'Canada', 'six channel partners', 'MINNEAPOLIS', 'November', "Cargill's food ingredients", 'applications business', 'six North American distribution partners', 'Univar Inc.', 'Gillco Ingredients', 'International Food Products Corporation', 'Batory Foods', 'Pearson Sales Company', 'St. Charles Trading', 'This move', 'customer experience', 'the supply chain', 'a platform', 'sustainable growth', 'a select group', 'committed channel partners', "today's rapidly changing marketplace", 'our customers', 'industry-leading distributor partners', 'who', 'house', 'broad product portfolios', 'one-stop convenience', 'regulatory support', 'flexible lead times', 'minimum order quantities', 'Pat Rogers', 'commercial leader', "Cargill's North America food ingredients business", 'We', 'these partners', 'those expectations', 'added value', 'our customers', 'The following six channel partners', "Cargill's food ingredients distribution network", 
# ...

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cargill consolidate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  food ingredient distribution network
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
# ...
